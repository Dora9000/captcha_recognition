# %%
import matplotlib
import cv2
import os
import pickle
import random
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pathlib
# Out:
# Using TensorFlow backend.

# %%
data = []
labels = []
random.seed(1234)

#берём пути к изображениям и рандомно перемешиваем
data_root = pathlib.Path("C:\\UIR\\samples\\sample_1\\500\\cut_letters")
imagePaths = list(data_root.glob('*/*'))
imagePaths = [str(path) for path in imagePaths]
random.shuffle(imagePaths)

#цикл по изображениям
for imagePath in imagePaths:
    #загружаем изображение, меняем размер на 28x28 пикселей и добавляем в список
    image = cv2.imread(imagePath)
    image = cv2.resize(image,(28,28))
    data.append(image)
    
    #извлекаем метку класса из пути к изображению и обновляем список меток
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)

# %%
# масштабируем интенсивности пикселей из диапазона [0,255] -> в диапазон [0, 1]
data = np.array(data,dtype="float") / 255.0
labels = np.array(labels)

# %%
# разбиваем данные на обучающую и тестовую выборки, используя 75% 
# данных для обучения и оставшиеся 25% для тестирования
(trainX,testX, trainY,testY) = train_test_split(data, labels, test_size = 0.25, random_state = 42)
print(testX.shape)
print(trainX.shape)
# Out:
# (4620, 28, 28, 3)
# (13860, 28, 28, 3)

# %%
#Конвертируем метки из целых чисел в векторы
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY) #находит все уникальные метки класса в testY, а затем преобразует их в метки One-Hot Encoding
testY = lb.transform(testY) #выполняет один шаг One-Hot Encoding исходя из найденных уникальных меток на предыдущем шаге

# %%
print('X_train shape:', trainX.shape)
print(trainX.shape[0], 'train samples')
print(testX.shape[0], 'test samples')
# Out:
# X_train shape: (13860, 28, 28, 3)
# 13860 train samples
# 4620 test samples

# %% [markdown]
# ## CNN Architecture

# %%
EPOCHS = 50
img_rows, img_cols = 28, 28
input_shape = (img_rows, img_cols, 3) #input_shape будет равен 28x28x3
num_classes = 28


model = Sequential()
model.add(Conv2D(filters=70,kernel_size=(3, 3),strides=(1, 1), activation='sigmoid', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2),strides=2, padding='same'))

model.add(Conv2D(filters=100,kernel_size=(3, 3),strides=(1, 1), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2),strides=2))

model.add(Conv2D(filters=150,kernel_size=(3, 3),strides=(1, 1), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2),strides=2))

model.add(Flatten())
model.add(Dense(300, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

#Компилируем модель, используя adadelta как оптимизатор и категориальную
# кросс-энтропию в качестве функции потерь. Добавляем метрики
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

# %%
#отобразим получившуюся модель
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 70)        1960
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 70)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 100)       63100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 100)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 150)         135150
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 150)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               45300
# _________________________________________________________________
# dense_2 (Dense)              (None, 28)                8428
# =================================================================
# Total params: 253,938
# Trainable params: 253,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import callbacks
#подключаем колбаски для работы tensorboard
#write tensorboard --logdir C:/UIR/network_15/logs in cmd
my_callbacks = [
    callbacks.TensorBoard(log_dir="C:\\UIR\\network_15\\logs", histogram_freq = 1, write_graph = True, write_images = True)
]

# %%
H = model.fit(trainX, trainY, verbose=2, validation_data=(testX, testY), epochs=EPOCHS, batch_size=32, callbacks=my_callbacks)
# Out:
# Train on 13860 samples, validate on 4620 samples
# Epoch 1/50
#  - 18s - loss: 3.3749 - accuracy: 0.0371 - val_loss: 3.3850 - val_accuracy: 0.0335
# Epoch 2/50
#  - 17s - loss: 3.0240 - accuracy: 0.1185 - val_loss: 2.1607 - val_accuracy: 0.2879
# Epoch 3/50
#  - 17s - loss: 0.9499 - accuracy: 0.7693 - val_loss: 0.2924 - val_accuracy: 0.9558
# Epoch 4/50
#  - 17s - loss: 0.1391 - accuracy: 0.9823 - val_loss: 0.0889 - val_accuracy: 0.9803
# Epoch 5/50
#  - 17s - loss: 0.0558 - accuracy: 0.9891 - val_loss: 0.0487 - val_accuracy: 0.9905
# Epoch 6/50
#  - 17s - loss: 0.0378 - accuracy: 0.9916 - val_loss: 0.0355 - val_accuracy: 0.9937
# Epoch 7/50
#  - 17s - loss: 0.0305 - accuracy: 0.9929 - val_loss: 0.0369 - val_accuracy: 0.9922
# Epoch 8/50
#  - 17s - loss: 0.0265 - accuracy: 0.9936 - val_loss: 0.0291 - val_accuracy: 0.9959
# Epoch 9/50
#  - 17s - loss: 0.0233 - accuracy: 0.9935 - val_loss: 0.0265 - val_accuracy: 0.9963
# Epoch 10/50
#  - 17s - loss: 0.0208 - accuracy: 0.9952 - val_loss: 0.0354 - val_accuracy: 0.9909
# Epoch 11/50
#  - 17s - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0247 - val_accuracy: 0.9959
# Epoch 12/50
#  - 17s - loss: 0.0167 - accuracy: 0.9959 - val_loss: 0.0242 - val_accuracy: 0.9959
# Epoch 13/50
#  - 17s - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.0238 - val_accuracy: 0.9961
# Epoch 14/50
#  - 18s - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0262 - val_accuracy: 0.9948
# Epoch 15/50
#  - 17s - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0251 - val_accuracy: 0.9957
# Epoch 16/50
#  - 17s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0239 - val_accuracy: 0.9963
# Epoch 17/50
#  - 16s - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0233 - val_accuracy: 0.9955
# Epoch 18/50
#  - 17s - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0317 - val_accuracy: 0.9929
# Epoch 19/50
#  - 18s - loss: 0.0094 - accuracy: 0.9980 - val_loss: 0.0226 - val_accuracy: 0.9961
# Epoch 20/50
#  - 18s - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.0222 - val_accuracy: 0.9961
# Epoch 21/50
#  - 19s - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0218 - val_accuracy: 0.9965
# Epoch 22/50
#  - 19s - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 23/50
#  - 22s - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0397 - val_accuracy: 0.9907
# Epoch 24/50
#  - 19s - loss: 0.0068 - accuracy: 0.9987 - val_loss: 0.0249 - val_accuracy: 0.9959
# Epoch 25/50
#  - 19s - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.0267 - val_accuracy: 0.9946
# Epoch 26/50
#  - 20s - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0295 - val_accuracy: 0.9944
# Epoch 27/50
#  - 19s - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0210 - val_accuracy: 0.9968
# Epoch 28/50
#  - 18s - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.0319 - val_accuracy: 0.9935
# Epoch 29/50
#  - 18s - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0234 - val_accuracy: 0.9959
# Epoch 30/50
#  - 19s - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0214 - val_accuracy: 0.9959
# Epoch 31/50
#  - 18s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.0226 - val_accuracy: 0.9963
# Epoch 32/50
#  - 19s - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0215 - val_accuracy: 0.9961
# Epoch 33/50
#  - 18s - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0219 - val_accuracy: 0.9968
# Epoch 34/50
#  - 19s - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0216 - val_accuracy: 0.9970
# Epoch 35/50
#  - 20s - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0283 - val_accuracy: 0.9944
# Epoch 36/50
#  - 20s - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0221 - val_accuracy: 0.9965
# Epoch 37/50
#  - 18s - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0239 - val_accuracy: 0.9961
# Epoch 38/50
#  - 18s - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0219 - val_accuracy: 0.9965
# Epoch 39/50
#  - 18s - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0216 - val_accuracy: 0.9965
# Epoch 40/50
#  - 18s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0253 - val_accuracy: 0.9961
# Epoch 41/50
#  - 19s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0222 - val_accuracy: 0.9959
# Epoch 42/50
#  - 18s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0235 - val_accuracy: 0.9965
# Epoch 43/50
#  - 17s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0224 - val_accuracy: 0.9959
# Epoch 44/50
#  - 17s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0281 - val_accuracy: 0.9950
# Epoch 45/50
#  - 18s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0211 - val_accuracy: 0.9965
# Epoch 46/50
#  - 18s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0216 - val_accuracy: 0.9970
# Epoch 47/50
#  - 18s - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0220 - val_accuracy: 0.9963
# Epoch 48/50
#  - 18s - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0223 - val_accuracy: 0.9965
# Epoch 49/50
#  - 19s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0210 - val_accuracy: 0.9970
# Epoch 50/50
#  - 18s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0212 - val_accuracy: 0.9972

# %%
model.save('model_15.h5')
f = open("C:\\UIR\\network_15\\bin_class.txt", "wb")
f.write(pickle.dumps(lb))
f.close()

# %% [markdown]
# ## Plots

# %%
#plotting training and validation loss
import matplotlib.pyplot as plt
loss = H.history['loss']
val_loss = H.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotting training and validation loss
import matplotlib.pyplot as plt
loss = H.history['loss']
loss = loss[4:50]
val_loss = H.history['val_loss']
val_loss = val_loss[4:50]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotting training and validation loss
import matplotlib.pyplot as plt
loss = H.history['loss']
loss = loss[4:30]
val_loss = H.history['val_loss']
val_loss = val_loss[4:30]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotting training and validation accuracy
acc = H.history['accuracy']
val_acc = H.history['val_accuracy']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotting training and validation accuracy
acc = H.history['accuracy']
acc = acc[3:]
val_acc = H.history['val_accuracy']
val_acc = val_acc[3:]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotting training and validation accuracy
acc = H.history['accuracy']
acc = acc[3:25]
val_acc = H.history['val_accuracy']
val_acc = val_acc[3:25]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, color='red', label='Training acc')
plt.plot(epochs, val_acc, color='green', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
PATH = "C:\\UIR\\samples\\sample_2\\300\\cut_letters\\2\\210056141.jpeg"

test_image = cv2.imread(PATH)
test_image = cv2.resize(test_image,(28,28))
cv2.imshow('image',test_image)
cv2.waitKey(0)
test_image = test_image.astype("float") / 255.0
test_image = test_image.reshape((1,test_image.shape[0], test_image.shape[1],test_image.shape[2]))
preds = model.predict(test_image)
i = preds.argmax(axis=1)[0]
test_label = lb.classes_[i]
print("Результат распознавания: " + test_label)
# Out:
# Результат распознавания: z
